# %% [markdown]
# # Long Baseline Study of Mira Variable Stars: Better Part Three
# ## 24-in Observations
# The majority of this notebook is taken from Emily's New Plate Analysis notebook, with adjustments made to calculate the magnitude in the end. Check each cell for multiple hashtags that indicate where you need to input your own info.

# %% [markdown]
# #### Step One
# Use Emily's Image Calibration notebook to sort and calibrate your observation files. Retrieve WCS files of your observation through whatever astrometry.net route you can take.

# %% [markdown]
# #### Step Two
# Do aperture photometry and calibrate with Gaia.

# %%
#Start with imports!
import cv2
import numpy as np
from astropy.io import fits
from astroquery.gaia import Gaia
from astropy.coordinates.sky_coordinate import SkyCoord
from astropy.wcs import WCS
import sep
sep.set_extract_pixstack(1000000)
sep.set_sub_object_limit(1000000)

from astropy.table import Table, hstack
from scipy.optimize import curve_fit
import csv
import math 
from scipy.stats import mode as spmode
import statistics

import matplotlib.pyplot as plt
from astropy.visualization import SqrtStretch
from astropy.visualization.mpl_normalize import ImageNormalize
from astropy.stats import SigmaClip
from photutils.background import Background2D, MedianBackground
from photutils.background import *
from photutils.datasets import make_100gaussians_image
from astropy.stats import biweight_location
from astropy.stats import mad_std
from astropy.stats import sigma_clipped_stats

import astropy.table
from matplotlib.backends.backend_pdf import PdfPages

import numpy as np
from astropy.wcs import WCS
from astropy.table import Table, hstack

import os
from astropy.io import ascii
import glob
from glob import glob

from astroquery.astrometry_net import AstrometryNet

import glob

from datetime import datetime
from astropy.time import Time
import matplotlib.dates as mdates

# %matplotlib widget

# sq func used in analysis 
def sq(x,a,b):
    return(a*x**(b/2))
import pandas as pd

mean = np.mean
std = np.std

# %%
# def ap_phot2 detects and subtracts the image background through photutils and then extracts objects from image with SEP, calculating a mag

def ap_phot2(data,  sigma):

    sigma_clip = SigmaClip(sigma = sigma)
    bkg_estimator = MMMBackground()

    bkg = Background2D(data,box_size=(msize, msize), sigma_clip=sigma_clip, bkg_estimator=bkg_estimator)
    data_sub = data - bkg.background

    objects = Table(sep.extract(data_sub, sigma, err = bkg.background_rms_median))

    ob_mask = np.where(objects['flag'] != 8)[0]
    objects = objects[ob_mask]

    objects['flux2'], sum_err, flag = sep.sum_circle(data=data_sub, x=objects['x'], y=objects['y'], r = ((objects['xmax'] -    objects['xmin'])/2), err=bkg.background_rms_median)

    return data_sub, objects

# %%
first_file = '/raid6/users/rantoine/2026-06-30/lights/6-30-26/6-30-26_c/6-30-26_R_Aql-001_60s_B__c.new'

# load the data
firstframe = fits.getdata(first_file)

# display the image
plt.figure(1) #Create new "figure" for this image
plt.imshow(firstframe,cmap='gray',vmin=np.percentile(firstframe,25),
           vmax=np.percentile(firstframe,99.9), origin = 'lower')

plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
path = '/raid6/users/rantoine/2026-06-30/lights/6-30-26/6-30-26_c/'

filename = '6-30-26_R_Aql*_c.new'

matches = sorted(glob.glob(path + filename))

msize=50

####### CHANGE TARGET LOCATION #######

tx, ty = (509, 514) #find using matplotlib widget of the image you displayed above

err = 10 #tolerance in pixel distance

fluxes = []

for filepath in matches:
    with fits.open(filepath) as hdu:
        data = hdu[0].data
        header = hdu[0].header

    data_sub, objects = ap_phot2(data, 5)

    df = objects.to_pandas()

    match = df[
        (df['x'].sub(tx).abs() <= err) &
        (df['y'].sub(ty).abs() <= err)
    ]

    print(f"\n{filepath}")
    if not match.empty:
        with pd.option_context('display.max_rows', None, 'display.max_columns', None):
            display(match)

        fluxes.append(match['flux2'])
        
    else:
        norm = ImageNormalize(stretch=SqrtStretch())   #to check where your star is and increase error tolerance
        plt.figure()
        plt.imshow(data, origin='lower', cmap='Greys_r', norm=norm, interpolation='nearest')
        plt.show()
  
fluxes

####### CHANGE FILE NAME FOR EACH DATE OF OBSERVATION #######

np.save('6_30_26_R_Aql_fluxes.npy', fluxes)
# Out:
# /raid6/users/rantoine/2026-06-30/lights/6-30-26/6-30-26_c/6-30-26_R_Aql
60s_B__c.new
#        thresh  npix  tnpix  xmin  xmax  ymin  ymax           x          y  \
# 21  81.709442   321    310   506   526   503   523  515.572886  513.33985
#
#           x2        y2        xy     errx2     erry2         errxy         a  \
# 21  6.682141  6.839203 -0.001954  0.000004  0.000004 -2.216897e-08  2.615192
#
#            b     theta       cxx       cyy       cxy      cflux         flux  \
# 21  2.584979 -1.558357  0.149653  0.146216  0.000086  745639.25  746334.9375
#
#            cpeak          peak  xcpeak  ycpeak  xpeak  ypeak  flag  \
# 21  21192.669922  23756.580078     516     513    516    514     0
#
#             flux2
# 21  745536.902483
# /raid6/users/rantoine/2026-06-30/lights/6-30-26/6-30-26_c/6-30-26_R_Aql-018_60s_B__c.new
#       thresh  npix  tnpix  xmin  xmax  ymin  ymax           x           y  \
# 25  81.72065   322    309   506   525   503   523  515.490106  513.519227
#
#           x2        y2       xy     errx2     erry2         errxy         a  \
# 25  6.185641  6.791246  0.38024  0.000004  0.000004  7.109733e-08  2.640932
#
#            b     theta       cxx       cyy       cxy        cflux        flux  \
# 25  2.449972  1.121653  0.162223  0.147757 -0.018166  747465.9375  748115.625
#
#            cpeak          peak  xcpeak  ycpeak  xpeak  ypeak  flag  \
# 25  23203.025391  26495.693359     515     514    515    514     0
#
#             flux2
# 25  744326.754919
# /raid6/users/rantoine/2026-06-30/lights/6-30-26/6-30-26_c/6-30-26_R_Aql-019_60s_B__c.new
#       thresh  npix  tnpix  xmin  xmax  ymin  ymax           x           y  \
# 22  82.05806   309    299   505   525   504   523  514.824511  513.787105
#
#        x2        y2        xy     errx2     erry2         errxy         a  \
# 22  6.997  6.220421  0.333423  0.000004  0.000004  1.282986e-07  2.668428
#
#            b     theta       cxx       cyy      cxy       cflux      flux  \
# 22  2.469192  0.354761  0.143284  0.161172 -0.01536  746853.875  747587.5
#
#            cpeak          peak  xcpeak  ycpeak  xpeak  ypeak  flag  \
# 22  21484.171875  24033.484375     515     514    515    514     0
#
#             flux2
# 22  747638.128699
# /raid6/users/rantoine/2026-06-30/lights/6-30-26/6-30-26_c/6-30-26_R_Aql-020_60s_B__c.new
#       thresh  npix  tnpix  xmin  xmax  ymin  ymax           x           y  \
# 23  81.95166   299    286   504   523   505   524  513.140771  514.494041
#
#          x2        y2        xy     errx2     erry2         errxy         a  \
# 23  5.98474  6.497731  0.539781  0.000003  0.000004  2.062938e-07  2.615121
#
#            b     theta       cxx       cyy       cxy      cflux         flux  \
# 23  2.375629  1.007198  0.168353  0.155062 -0.027971  743966.75  744663.8125
#
#            cpeak          peak  xcpeak  ycpeak  xpeak  ypeak  flag  \
# 23  23276.589844  26600.015625     513     515    513    515     0
#
#             flux2
# 23  743106.687249
# /raid6/users/rantoine/2026-06-30/lights/6-30-26/6-30-26_c/6-30-26_R_Aql-021_60s_B__c.new
#        thresh  npix  tnpix  xmin  xmax  ymin  ymax           x           y  \
# 18  82.046967   298    283   507   526   504   524  515.920525  514.066274
#
#           x2        y2        xy     errx2     erry2         errxy         a  \
# 18  5.136446  6.128184  0.498328  0.000003  0.000004  3.970132e-08  2.517006
#
#            b     theta       cxx       cyy       cxy        cflux      flux  \
# 18  2.220205  1.176861  0.196235  0.164478 -0.031915  745999.5625  746545.5
#
#            cpeak          peak  xcpeak  ycpeak  xpeak  ypeak  flag  \
# 18  27077.533203  31204.152344     516     514    516    514     0
#
#             flux2
# 18  745142.641475
# /raid6/users/rantoine/2026-06-30/lights/6-30-26/6-30-26_c/6-30-26_R_Aql-022_60s_B__c.new
#        thresh  npix  tnpix  xmin  xmax  ymin  ymax           x           y  \
# 21  81.929932   288    275   507   525   505   524  515.616425  514.126548
#
#           x2       y2        xy     errx2     erry2         errxy         a  \
# 21  5.233782  5.84219  0.349822  0.000003  0.000003  1.196207e-07  2.449811
#
#            b     theta       cxx       cyy       cxy        cflux  \
# 21  2.252642  1.143279  0.191834  0.171857 -0.022974  749062.3125
#
#            flux         cpeak          peak  xcpeak  ycpeak  xpeak  ypeak  \
# 21  749719.1875  27487.330078  31785.650391     516     514    516    514
#
#     flag          flux2
# 21     0  746428.925405
# /raid6/users/rantoine/2026-06-30/lights/6-30-26/6-30-26_c/6-30-26_R_Aql-023_60s_B__c.new
#        thresh  npix  tnpix  xmin  xmax  ymin  ymax           x           y  \
# 24  81.936638   300    285   504   523   505   524  513.253439  514.654108
#
#           x2        y2        xy     errx2     erry2         errxy         a  \
# 24  6.441668  5.764947  0.297942  0.000004  0.000003  1.032342e-07  2.560107
#
#            b     theta       cxx       cyy       cxy        cflux  \
# 24  2.377492  0.360981  0.155611  0.173878 -0.016084  749464.5625
#
#            flux         cpeak         peak  xcpeak  ycpeak  xpeak  ypeak  \
# 24  750093.6875  23750.515625  26854.21875     513     515    513    515
#
#     flag          flux2
# 24     0  748490.626864
# /raid6/users/rantoine/2026-06-30/lights/6-30-26/6-30-26_c/6-30-26_R_Aql-024_60s_B__c.new
#        thresh  npix  tnpix  xmin  xmax  ymin  ymax           x           y  \
# 22  81.895508   306    291   504   524   505   525  513.881836  514.611158
#
#          x2        y2        xy     errx2     erry2         errxy        a  \
# 22  6.39893  6.001967  0.449867  0.000004  0.000004  1.315454e-07  2.58692
#
#            b     theta       cxx       cyy       cxy       cflux         flux  \
# 22  2.389297  0.577642  0.157104  0.167495 -0.023551  750857.125  751397.9375
#
#            cpeak          peak  xcpeak  ycpeak  xpeak  ypeak  flag  \
# 22  23562.324219  26597.355469     514     515    514    515     0
#
#             flux2
# 22  751846.064832
# /raid6/users/rantoine/2026-06-30/lights/6-30-26/6-30-26_c/6-30-26_R_Aql-025_60s_B__c.new
#        thresh  npix  tnpix  xmin  xmax  ymin  ymax           x           y  \
# 24  81.785706   296    285   507   525   505   525  515.966663  514.246179
#
#           x2        y2        xy     errx2     erry2         errxy         a  \
# 24  5.397434  5.927732  0.327943  0.000003  0.000003  1.314766e-07  2.466639
#
#            b     theta       cxx       cyy       cxy       cflux         flux  \
# 24  2.289292  1.125356  0.185898  0.169268 -0.020569  752078.125  752628.0625
#
#            cpeak          peak  xcpeak  ycpeak  xpeak  ypeak  flag  \
# 24  26939.205078  31005.082031     516     514    516    514     0
#
#             flux2
# 24  748536.978242
# /raid6/users/rantoine/2026-06-30/lights/6-30-26/6-30-26_c/6-30-26_R_Aql-026_60s_B__c.new
#        thresh  npix  tnpix  xmin  xmax  ymin  ymax          x          y  \
# 27  81.770638   306    293   507   526   505   525  515.82941  514.61851
#
#           x2        y2        xy     errx2     erry2         errxy         a  \
# 27  6.192887  6.463388  0.676558  0.000003  0.000004  1.407984e-07  2.649166
#
#            b     theta       cxx       cyy       cxy        cflux  \
# 27  2.374488  0.884053  0.163343  0.156507 -0.034196  750398.9375
#
#            flux         cpeak          peak  xcpeak  ycpeak  xpeak  ypeak  \
# 27  751088.8125  23450.371094  26785.685547     516     515    516    515
#
#     flag         flux2
# 27     0  748871.00446
# /raid6/users/rantoine/2026-06-30/lights/6-30-26/6-30-26_c/6-30-26_R_Aql-027_60s_B__c.new
#        thresh  npix  tnpix  xmin  xmax  ymin  ymax           x           y  \
# 30  81.931763   310    298   503   522   505   525  512.293703  514.689257
#
#           x2        y2        xy     errx2     erry2         errxy         a  \
# 30  5.709703  6.933358  0.462578  0.000004  0.000004  1.071686e-07  2.662432
#
#            b     theta       cxx       cyy       cxy     cflux       flux  \
# 30  2.356802  1.247113  0.176092  0.145014 -0.023497  747798.0  748370.75
#
#            cpeak          peak  xcpeak  ycpeak  xpeak  ypeak  flag  \
# 30  23729.646484  26964.449219     512     515    512    515     0
#
#             flux2
# 30  745752.718955

# %% [markdown]
# #### Step Three
# Repeat for each night of observations.

# %% [markdown]
# #### Step Four
# Combine your observations and calculate the magnitude.

# %%
flux_files = sorted(glob.glob('/raid6/users/rantoine/Mira_Notebooks/Better_Part_Three/*R_Aql_fluxes.npy'))

dates = []
avg_flux = []
for filepath in flux_files:
    filename = os.path.basename(filepath)
    date_str = filename.split('_R_Aql')[0] #taking the date from the filename
    date_time = datetime.strptime(date_str, "%m_%d_%y")
    #date = Time(date_time, scale="utc")
    
    df = np.load(filepath)

    flux = df[0]
    
    avg_flux.append(np.mean(flux))
    dates.append(date_time)
print(avg_flux)
print(dates)

df = pd.DataFrame({'Date': pd.to_datetime(dates), 'Avg_Flux': avg_flux})
# Out:
# [738243.601352234, 1066880.1784546669, 2510528.1275021373, 2341451.4246088406, 1315626.9851559065, 1392729.857419396, 1339551.6025048061]
# [datetime.datetime(2026, 6, 30, 0, 0), datetime.datetime(2026, 7, 6, 0, 0), datetime.datetime(2026, 7, 11, 0, 0), datetime.datetime(2026, 7, 12, 0, 0), datetime.datetime(2026, 7, 13, 0, 0), datetime.datetime(2026, 7, 14, 0, 0), datetime.datetime(2026, 7, 24, 0, 0)]

# %%
# Now, let's plot our flux lightcurve!
plt.rcParams.update({
    'font.size': 14,
    'axes.titlesize': 16,
    'axes.labelsize': 16,
    'xtick.labelsize': 13,
    'ytick.labelsize': 13,
    'legend.fontsize': 13,
    'figure.titlesize': 18
})

fig, ax = plt.subplots(figsize=(10, 5))

ax.scatter(df['Date'], df['Avg_Flux'], color='#9C179E', s=10)
ax.set_xlabel('Time (Date)')
ax.set_ylabel('Flux')
ax.invert_yaxis()
ax.set_title('Yerkes Flux Light Curve of R Aql')

fig.autofmt_xdate()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
plt.close()
